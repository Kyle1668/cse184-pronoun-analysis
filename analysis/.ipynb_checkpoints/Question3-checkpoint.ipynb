# %%
# What are the most common roles in tech that have gendered job postings?
# Approach:
# 1. First filter all the jobs that have gendered job postings, using the list 'masculine_themed_wording'
# 2. After getting all the jobs, create a new data frame that has the title and description
# 3. Using the same method as filtering the gendering the job postings, we can find specific titles of the job
# 4. Create a histogram of those job titles to show a comparison -> 

import numpy as np
import pandas as pd
import matplotlib as plt
import csv
import requests
import collections
from bs4 import BeautifulSoup
pd.set_option("display.max_rows", 1000) 
pd.set_option("display.max_columns", 13)

gender_pronouns = [
    "he",
    "him",
    "she",
    "her",
    "his",
    "hers"
]

# Words are from articles and websites that define the words as masculine (sources such as WIRED)
masculine_themed_wording = [
    "competitive",
    "dominate",
    "leader",
    "rock star",
    "rockstar",
    "guru",
    "ninja",
    "hacker",
    "superhero",
    "prove themselves",
    "analyze",
    "determine",
    "crush it",
    "world class",
    "superior",
    "ambitious",
    "aggressive",
    "leader"
]

job_positions = [
    "developer",
    "engineer",
    "software engineer",
    "software developer",
    "product manager",
    "manager",
    "product developer",
    "tech lead",
    "lead",
    "analyst",
    "head",
    "designer"
]

states = ['AL',
    'AK',
    'AZ',
    'AR',
    'CA',
    'CO',
    'CT',
    'DE',
    'DC',
    'FL',
    'GA',
    'HI',
    'ID',
    'IL',
    'IN',
    'IA',
    'KS',
    'KY',
    'LA',
    'ME',
    'MD',
    'MA',
    'MI',
    'MN',
    'MS',
    'MO',
    'MT',
    'NE',
    'NV',
    'NH',
    'NJ',
    'NM',
    'NY',
    'NC',
    'ND',
    'OH',
    'OK',
    'OR',
    'PA',
    'RI',
    'SC',
    'SD',
    'TN',
    'TX',
    'UT',
    'VT',
    'VA',
    'WA',
    'WV',
    'WI',
    'WY' ]

total_jobs = 22000
jobs = pd.read_csv("../data/derived_job_data.csv")
type(jobs)
# Out:
# pandas.core.frame.DataFrame

# %%
#jobs

# %%
# desc is the job description from the Kaggle file
desc = jobs["jobdescription"]

# The type of desc is:  pandas.core.series.Series
type(desc)

desc
# Out:
# 0        Looking for Selenium engineers...must have sol...
# 1        The University of Chicago has a rapidly growin...
# 2        GalaxE.SolutionsEvery day, our solutions affec...
# 3        Java DeveloperFull-time/direct-hireBolingbrook...
# 4        Midtown based high tech firm has an immediate ...
# 5        We are looking for a Senior SAP FICO Architect...
# 6        Network Engineer Job Description A Network Eng...
# 7        Bluebeam is looking for talented sr. web devel...
# 8        This is a fulltime position for a Javascript d...
# 9        SummaryOur client is the leading provider of o...
# 10       JOB DESCRIPTION:As a senior member of the team...
# 11       Must have skills: UNIX, IAM (Identity Access M...
# 12       VanderHouwen has more jobs you may like!  Find...
# 13       Genesis10 is currently seeking a Sales Enginee...
# 14       VanderHouwen has more jobs you may like! Find ...
# 15       Windows Systems Administrator The Windows Syst...
# ...

# %%
# Empty list, add jobs that have "masculine" words to the array

#if desc.str.find("competitive") != -1:
#    count = count + 1
#count
title_DF = jobs["jobtitle"]
title_DF
# Out:
# 0                                 AUTOMATION TEST ENGINEER
# 1                            Information Security Engineer
# 2                             Business Solutions Architect
# 3        Java Developer (mid level)- FT- GREAT culture,...
# 4                                          DevOps Engineer
# 5                                       SAP FICO Architect
# 6                                         Network Engineer
# 7        Sr. Web Application Developer (Cloud Team) - C...
# 8                                      Front End Developer
# 9                             Application Support Engineer
# 10                              OpenStack Engineer - 12185
# 11           9001 Data Security Administrator - Unix & IAM
# 12                               Software Engineer Manager
# 13                             Sales Engineer - Los Angles
# 14                                         Project Manager
# 15                            Windows System Administrator
# ...

# %%
# Returns the index it's found when using str.find


# "prove themselves","analyze","determine",
# "crush it", "world class", "superior", "ambitious", "aggressive",


# Prints the job description for any job that contains "competitive" in the description
# FOR THE STRING COMPETITIVE
print("Competitive \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("competitive") > -1)
#print(type(x))
#print(x)

count = 0
arr = []

# Gets count of jobs that uses that specific string in job description
for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr.append(item)
        count += 1
#print("length of array", len(arr))
#print("count using COMPETITIVE: ", count)
print("% that uses competitive", (count/total_jobs) * 100)

# This loop will get the POSITION of the jobs that contain the string
# when i == value contained in arr, then print the job title
# then store into data frame
for i in arr:
    print(jobs["jobtitle"].iloc[i])
    #print(0)

    
    
    
# FOR THE STRING DOMINATE
print()
print("Dominate \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("dominate") > -1)
count = 0
arr2 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr2.append(item)
        count += 1
print("% that uses dominate", (count/total_jobs) * 100)
        
for i in arr2:
    print(jobs['jobtitle'].iloc[i])

    
# FOR THE STRING LEADER
print()
print("Leader \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("leader") > -1)
count = 0
arr3 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr3.append(item)
        count += 1
print("% that uses leader", (count/total_jobs) * 100)
for i in arr3:
    print(jobs['jobtitle'].iloc[i])
    
# FOR THE STRING rock star
print()
print("Rock star \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("rock star") > -1)
count = 0
arr4 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr4.append(item)
        count += 1
print("% that uses rock star", (count/total_jobs) * 100)
for i in arr4:
    print(jobs['jobtitle'].iloc[i])

# FOR THE STRING rockstar
print()
print("Rockstar \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("rockstar") > -1)
count = 0
arr5 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr5.append(item)
        count += 1
print("% that uses rockstar", (count/total_jobs) * 100)
for i in arr5:
    print(jobs['jobtitle'].iloc[i])
    
# FOR THE STRING guru
print()
print("Guru \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("guru") > -1)
count = 0
arr6 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr6.append(item)
        count += 1
print("% that uses guru", (count/total_jobs) * 100)

for i in arr6:
    print(jobs['jobtitle'].iloc[i])
    
# FOR THE STRING ninja
print()
print("Ninja \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("ninja") > -1)
count = 0
arr7 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr7.append(item)
        count += 1

print("% that uses ninja", (count/total_jobs) * 100)

for i in arr7:
    print(jobs['jobtitle'].iloc[i])

# FOR THE STRING hacker
print()
print("Hacker \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("hacker") > -1)
count = 0
arr8 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr8.append(item)
        count += 1
print("% that uses hacker", (count/total_jobs) * 100)
        
for i in arr8:
    print(jobs['jobtitle'].iloc[i])

# FOR THE STRING superhero
print()
print("Superhero \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("superhero") > -1)
count = 0
arr9 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr9.append(item)
        count += 1
print("% that uses superhero", (count/total_jobs) * 100)
for i in arr9:
    print(jobs['jobtitle'].iloc[i])
    

# FOR THE STRING prove themselves
print()
print("Prove themselves \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("prove themselves") > -1)
count = 0
arr10 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr10.append(item)
        count += 1
print("% that uses prove themselves", (count/total_jobs) * 100)
for i in arr10:
    print(jobs['jobtitle'].iloc[i])


# FOR THE STRING analyze
print()
print("Analyze \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("analyze") > -1)
count = 0
arr11 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr11.append(item)
        count += 1
print("% that uses analyze", (count/total_jobs) * 100)
for i in arr11:
    print(jobs['jobtitle'].iloc[i])

# FOR THE STRING determine
print()
print("Determine \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("determine") > -1)
count = 0
arr12 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr12.append(item)
        count += 1
print("% that uses determine", (count/total_jobs) * 100)
for i in arr12:
    print(jobs['jobtitle'].iloc[i])
    

# FOR THE STRING crush it
print()
print("Crush it \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("crush it") > -1)
count = 0
arr13 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr13.append(item)
        count += 1
print("% that uses crush it", (count/total_jobs) * 100)
for i in arr13:
    print(jobs['jobtitle'].iloc[i])
  

#FOR THE STRING world class
print()
print("World Class \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("world class") > -1)
count = 0
arr14 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr14.append(item)
        count += 1
print("% that uses world class", (count/total_jobs) * 100)
for i in arr14:
    print(jobs['jobtitle'].iloc[i])
    

# FOR THE STRING superior
print()
print("Superior \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("superior") > -1)
count = 0
arr15 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr15.append(item)
        count += 1
print("% that uses superior", (count/total_jobs) * 100)
for i in arr15:
    print(jobs['jobtitle'].iloc[i])  

 # FOR THE STRING ambitious 
print()
print("Ambituous \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("ambituous") > -1)
count = 0
arr16 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr16.append(item)
        count += 1
print("% that uses ambituous", (count/total_jobs) * 100)
for i in arr16:
    print(jobs['jobtitle'].iloc[i])  

# FOR THE STRING aggressive 
print()
print("Aggressive \n")
x = jobs["jobdescription"].where(jobs["jobdescription"].str.find("aggressive") > -1)
count = 0
arr17 = []

for item, frame in x.iteritems():
    if pd.notnull(frame):
        arr17.append(item)
        count += 1
print("% that uses aggressive", (count/total_jobs) * 100)
for i in arr17:
    print(jobs['jobtitle'].iloc[i])
# Out:
# Competitive
#
# % that uses competitive 7.122727272727272
# 1001 Selenium Automation testing
# Jr Business Analysts
# Business Systems Analyst
# Account Manager
# Business Development Manager
# IT Project Manager (Mobile Apps)
# Manager - QA, Automation, Management, Team Development, SDLC, Agile,SOA
# IT Buyer
# Entry Level Business Systems Analyst
# Software Engineer, Hadoop
# Senior Consultant w/ TOP SECRET CLEARANCE
# Hybrid Mobile Developer - HTML5, CSS3, AngularJS
# Insurance Consulting Leader
# Senior Back End Developer - Python, Big Data Processing
# Solution Architect, Master Data Management (MDM) - East
# Enterprise Information Management (EIM) Principal Consultant (Remote)
# Lead Android Developer - Java, Android SDK, Android
# MBA Intern - Enterprise Market Strategy
# Java Lead / Java Developer with spring
# Senior Developer - HEAVILYFunded, Revolutionary Biotech Co! RELO
# Platform Engineer - AWS, DevOps, PHP
# Software Engineer - Full Stack Cloud product development
# ...

# %%
# With all the arrays, add all numbers into an array without repeating elements
# Example: [1,2,2,3,4] - only put 2 once

complete_job_list = arr + arr2 + arr3 + arr4 + arr5 + arr6 + arr7 + arr8 + arr9 + arr10 + arr11 + arr12 + arr13 + arr14 + arr15 + arr16 + arr17
print("With duplicates", complete_job_list)


# ^^ Remove duplicates from this list by converting to a set then back to a list
complete_job_list_exclusives = list(set(complete_job_list))
print("Without duplicates")
print(complete_job_list_exclusives)

print("All", len(complete_job_list))
print("Exclusive", len(complete_job_list_exclusives))

job_title_list = []
for i in complete_job_list_exclusives:
    job_title_list.append(jobs['jobtitle'].iloc[i])

job_desc_list = []
for i in complete_job_list_exclusives:
    job_desc_list.append(jobs['jobdescription'].iloc[i])
    
job_location_list = []
for i in complete_job_list_exclusives:
    job_location_list.append(jobs['joblocation_address'].iloc[i])

# Turn the exclusive jobs list into a dataframe to make searching and visualization easier
dataframe = pd.DataFrame(complete_job_list_exclusives, index = complete_job_list_exclusives, columns = ["Job Number"])
dataframe


print(len(job_location_list))
print(len(job_desc_list))
dataframe['Job Titles'] = job_title_list
dataframe['Job Desc'] = job_desc_list
dataframe['Job Location'] = job_location_list

# dataframe

#there are 8087 exclusive jobs that use at least one of the words in the list above
# Out:
# With duplicates [27, 56, 76, 78, 136, 137, 195, 232, 274, 307, 321, 328, 340, 382, 383, 419, 421, 433, 454, 461, 469, 482, 499, 508, 536, 567, 574, 605, 610, 624, 632, 641, 658, 677, 703, 737, 746, 748, 792, 807, 811, 828, 831, 842, 887, 900, 911, 914, 922, 928, 938, 941, 956, 973, 974, 977, 998, 1020, 1049, 1051, 1076, 1112, 1122, 1130, 1135, 1176, 1219, 1222, 1226, 1227, 1249, 1278, 1288, 1298, 1321, 1324, 1327, 1329, 1334, 1354, 1388, 1391, 1392, 1398, 1430, 1443, 1450, 1456, 1492, 1495, 1508, 1532, 1547, 1565, 1570, 1590, 1629, 1632, 1643, 1674, 1699, 1705, 1707, 1712, 1714, 1729, 1731, 1770, 1827, 1853, 1862, 1889, 1890, 1988, 2011, 2050, 2088, 2093, 2104, 2118, 2161, 2183, 2234, 2265, 2270, 2286, 2295, 2330, 2391, 2396, 2438, 2440, 2442, 2505, 2539, 2567, 2589, 2608, 2619, 2623, 2627, 2634, 2655, 2673, 2687, 2702, 2711, 2717, 2762, 2791, 2800, 2813, 2815, 2836, 2847, 2851, 2855, 2862, 2919, 2929, 2931, 2947, 2951, 2974, 2977, 2986, 2990, 2998, 3017, 3020, 3026, 3043, 3052, 3066
# ...

# %% [markdown]
# # Find jobs broken down by state

# %%
# Create a dictionary for the states
# Create a loop that goes through states list (ex: for key in states)
# have a counter variable (value) that increments each time state is found
# append that value to that key and value to the dictionary


job_dict = {}
job_list = []
drop_list = []
# states list already defined in the top cell
print(states)
count = 0

# Creates the state column
dataframe['State'] = dataframe['Job Location'].apply(lambda x: pd.Series(str(x).split(", ")[-1]))
dataframe

for state in dataframe['State']:
    #print(state)
    if state not in states:
        drop_list.append(state)
        #print(drop_list)


# Creates the counts for each state then drops rows that aren't in the state list
state_count = dataframe['State'].value_counts()
state_count = state_count.drop(labels = drop_list)

print(state_count)
print(type(state_count))


#Make into dataframe
state_count_df = state_count.to_frame()

# Export as CSV
state_count_csv = state_count_df.to_csv("state count.csv", index = True)
state_count_csv
# Export as Dictionary
job_dict = state_count.to_dict()
job_dict
# Out:
# ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']
# CA    1535
# TX     767
# NY     737
# GA     715
# NJ     627
# WA     521
# MA     515
# VA     304
# PA     284
# CT     279
# IL     220
# MD     190
# FL     143
# DC     130
# OH     109
# WI     107
# NC     101
# CO      95
# MI      89
# MN      78
# MO      78
# AZ      50
# RI      40
# TN      33
# IA      28
# NE      26
# NV      23
# NH      23
# OR      18
# KS      18
# ME      18
# SC      18
# DE      17
# AL      17
# IN      17
# UT      13
# LA      12
# KY      11
# ID       9
# OK       7
# HI       3
# WV       3
# AR       2
# SD       2
# VT       2
# NM       2
# AK       1
# MS       1
# WY       1
# Name: State, dtype: int64
# ...

# %%
import geopandas as gpd
import pandas as pd
import pandas_bokeh
from shapely.geometry import Point, Polygon
# %matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt
pandas_bokeh.output_notebook()



state_count.plot_bokeh(kind = "bar", xlabel = "State", ylabel = "Number of Jobs", title = "Number of Jobs by Location that use masculine themed words/phrases")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1789">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="bc7a0850-90cc-4a9a-8435-9a82aafc63a6" data-root-id="1827"></div>
# Figure(id='1827', ...)

# %%
# Create USA Map 
import geopandas as gdp
state_map = gpd.read_file("states.geojson")
state_map
# Out:
#               STATE_NAME  REGION  POPESTIMATE2010  POPESTIMATE2011  \
# 0                 Hawaii       4          1363817          1378323
# 1             Washington       4          6741386          6819155
# 2                Montana       4           990507           996866
# 3                  Maine       1          1327568          1327968
# 4           North Dakota       2           674518           684830
# 5           South Dakota       2           816227           823338
# 6                Wyoming       4           564376           567602
# 7              Wisconsin       2          5690403          5705812
# 8                  Idaho       4          1570912          1583180
# 9                Vermont       1           625842           626210
# 10             Minnesota       2          5310711          5345967
# 11                Oregon       4          3837073          3865845
# 12         New Hampshire       1          1316700          1318345
# ...

# %%
state_map.plot(figsize=(20,20))

# %% [markdown]
# # IMPLEMENT NLTK WORD STEMMING HERE

# %%
import nltk









#Find String "developer", trying to find way to find every instance of the string(s)

print("The following string checks are checking whether the position is mentioned") 
print("anywhere in the JOB DESCRIPTIONS \n")        
y = dataframe["Job Titles"].where(dataframe["Job Desc"].str.find("developer") > -1)
count = 0
desc_arr = [] # not sure if this array is needed yet, search for the positions

for item, frame in y.iteritems():
    if pd.notnull(frame):
        count+=1
        desc_arr.append(item)
print("Uses the word(s) developer: ", count)
#print(desc_arr)


y = dataframe["Job Titles"].where(dataframe["Job Desc"].str.find("engineer") > -1)
count = 0
desc_arr2 = [] # not sure if this array is needed yet, search for the positions

for item, frame in y.iteritems():
    if pd.notnull(frame):
        count+=1
        desc_arr2.append(item)
print("Uses the word(s) engineer: ", count)



#Find String "software engineer", trying to find way to find every instance of the string(s)
y = dataframe["Job Titles"].where(dataframe["Job Desc"].str.find("software engineerZ") > -1)
count = 0
desc_arr3 = [] # not sure if this array is needed yet, search for the positions

for item, frame in y.iteritems():
    if pd.notnull(frame):
        count+=1
        desc_arr3.append(item)
print("Uses the word(s) software engineer: ", count)


#Find String "software developer", trying to find way to find every instance of the string(s)
y = dataframe["Job Titles"].where(dataframe["Job Desc"].str.find("software developer") > -1)
count = 0
desc_arr4 = [] # not sure if this array is needed yet, search for the positions

for item, frame in y.iteritems():
    if pd.notnull(frame):
        count+=1
        desc_arr4.append(item)
print("Uses the word(s) software developer: ", count)


#Find String "product manager", trying to find way to find every instance of the string(s)
y = dataframe["Job Titles"].where(dataframe["Job Desc"].str.find("product manager") > -1)
count = 0
desc_arr5 = [] # not sure if this array is needed yet, search for the positions

for item, frame in y.iteritems():
    if pd.notnull(frame):
        count+=1
        desc_arr5.append(item)
print("Uses the word(s) product manager: ", count)


#Find String "manager", trying to find way to find every instance of the string(s)
y = dataframe["Job Titles"].where(dataframe["Job Desc"].str.find("manager") > -1)
count = 0
desc_arr6 = [] # not sure if this array is needed yet, search for the positions

for item, frame in y.iteritems():
    if pd.notnull(frame):
        count+=1
        desc_arr6.append(item)
print("Uses the word(s) manager: ", count)


#Find String "product developer", trying to find way to find every instance of the string(s)
y = dataframe["Job Titles"].where(dataframe["Job Desc"].str.find("product developer") > -1)
count = 0
desc_arr7 = [] # not sure if this array is needed yet, search for the positions

for item, frame in y.iteritems():
    if pd.notnull(frame):
        count+=1
        desc_arr7.append(item)
print("Uses the word(s) product developer: ", count)


#Find String "tech lead", trying to find way to find every instance of the string(s)
y = dataframe["Job Titles"].where(dataframe["Job Desc"].str.find("tech lead") > -1)
count = 0
desc_arr8 = [] # not sure if this array is needed yet, search for the positions

for item, frame in y.iteritems():
    if pd.notnull(frame):
        count+=1
        desc_arr8.append(item)
print("Uses the word(s) tech lead: ", count)



#Find String "lead", trying to find way to find every instance of the string(s)
y = dataframe["Job Titles"].where(dataframe["Job Desc"].str.find("lead") > -1)
count = 0
desc_arr9 = [] # not sure if this array is needed yet, search for the positions

for item, frame in y.iteritems():
    if pd.notnull(frame):
        count+=1
        desc_arr9.append(item)
print("Uses the word(s) lead: ", count)


#Find String "analyst", trying to find way to find every instance of the string(s)
y = dataframe["Job Titles"].where(dataframe["Job Desc"].str.find("analyst") > -1)
count = 0
desc_arr10 = [] # not sure if this array is needed yet, search for the positions

for item, frame in y.iteritems():
    if pd.notnull(frame):
        count+=1
        desc_arr10.append(item)
print("Uses the word(s) analyst: ", count)

#Find String "head", trying to find way to find every instance of the string(s)
y = dataframe["Job Titles"].where(dataframe["Job Desc"].str.find("head") > -1)
count = 0
desc_arr11 = [] # not sure if this array is needed yet, search for the positions

for item, frame in y.iteritems():
    if pd.notnull(frame):
        count+=1
        desc_arr11.append(item)
print("Uses the word(s) head: ", count)


#Find String "designer", trying to find way to find every instance of the string(s)
y = dataframe["Job Titles"].where(dataframe["Job Desc"].str.find("designer") > -1)
count = 0
desc_arr12 = [] # not sure if this array is needed yet, search for the positions

for item, frame in y.iteritems():
    if pd.notnull(frame):
        count+=1
        desc_arr12.append(item)
print("Uses the word(s) designer: ", count)



#Find String "software", trying to find way to find every instance of the string(s)
y = dataframe["Job Titles"].where(dataframe["Job Desc"].str.find("software") > -1)
count = 0
desc_arr13 = [] # not sure if this array is needed yet, search for the positions

for item, frame in y.iteritems():
    if pd.notnull(frame):
        count+=1
        desc_arr13.append(item)
print("Uses the word(s) software: ", count)

total_desc_arr = desc_arr + desc_arr2 + desc_arr3 + desc_arr4 + desc_arr5 + desc_arr6 + desc_arr7 + desc_arr8 + desc_arr9 + desc_arr10 + desc_arr11 + desc_arr12 + desc_arr13
total_desc_arr
# Out:
# The following string checks are checking whether the position is mentioned
# anywhere in the JOB DESCRIPTIONS
#
# Uses the word(s) developer:  1452
# Uses the word(s) engineer:  2302
# Uses the word(s) software engineer:  0
# Uses the word(s) software developer:  159
# Uses the word(s) product manager:  134
# Uses the word(s) manager:  1385
# Uses the word(s) product developer:  1
# Uses the word(s) tech lead:  31
# Uses the word(s) lead:  5727
# Uses the word(s) analyst:  696
# Uses the word(s) head:  570
# Uses the word(s) designer:  231
# Uses the word(s) software:  3829
# [9,
#  20,
#  25,
#  29,
#  30,
#  57,
#  76,
#  98,
#  116,
#  138,
#  140,
#  166,
#  177,
#  179,
#  185,
#  219,
#  230,
#  247,
#  254,
#  259,
#  260,
#  270,
#  298,
#  314,
#  320,
#  323,
#  326,
#  328,
#  347,
#  352,
#  407,
#  436,
#  459,
#  460,
#  479,
#  488,
#  525,
#  530,
#  534,
#  560,
#  571,
#  574,
#  587,
#  591,
#  592,
#  598,
#  608,
#  645,
#  648,
#  665,
#  694,
#  700,
#  701,
# ...

# %% [markdown]
# ## What we see here is that more leadership positions such as "lead" and "engineer", but terms like "software engineer" don't even appear
